# %%
#Fully-Connected Multi-Layer Perceptron (MLP)

# %%
# !pip install torch torchvision

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
#defininf of MLP Model
class MLP(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc3 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu(out)
        out = self.fc3(out)
        return out

# %%
input_size = 128 * 128 * 3  # Input size for a 128x128 RGB image flattened
hidden_size = 256  # Size of the hidden layer
output_size = 10
num_epochs = 5
batch_size = 32
learning_rate = 0.001

# %%
# Example dataset (placeholders for actual visual and trajectory data)
visual_data = torch.randn(500, input_size)  # 500 samples of 128x128 RGB images flattened
trajectory_data = torch.randn(500, output_size)  # Corresponding trajectory weights

# %%
# Dataset and DataLoader
dataset = torch.utils.data.TensorDataset(visual_data, trajectory_data)
train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
#Intilization of model, criterion, and optimizer
model = MLP(input_size, hidden_size, output_size)
criterion = nn.MSELoss()  # Using MSE loss as mentioned in the paper for trajectory prediction
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Training loop
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, trajectories) in enumerate(train_loader):
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, trajectories)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{total_step}], Loss: {loss.item():.4f}')

print('Finished Training')
# Out:
# Epoch [1/5], Step [10/16], Loss: 0.9877
# Epoch [2/5], Step [10/16], Loss: 1.0112
# Epoch [3/5], Step [10/16], Loss: 1.3165
# Epoch [4/5], Step [10/16], Loss: 0.3808
# Epoch [5/5], Step [10/16], Loss: 0.1587
# Finished Training

# %%
#Convolutional Neural Network (CNN)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
#defining the model

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1)
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(32 * 32 * 32, 256)
        self.fc2 = nn.Linear(256, 10)  # Example output size

    def forward(self, x):
        out = self.conv1(x)
        out = self.relu(out)
        out = self.pool(out)
        out = self.conv2(out)
        out = self.relu(out)
        out = self.pool(out)
        out = out.view(out.size(0), -1)  # Flatten the tensor
        out = self.fc1(out)
        out = self.relu(out)
        out = self.fc2(out)
        return out

# %%
# Hyperparameters
num_epochs = 5
batch_size = 32
learning_rate = 0.001

# %%
# Example dataset (placeholders for actual visual and trajectory data)
visual_data = torch.randn(500, 3, 128, 128)  # 500 samples of 128x128 RGB images
trajectory_data = torch.randn(500, 10)  # Corresponding trajectory weights

# %%
# Dataset and DataLoader
dataset = torch.utils.data.TensorDataset(visual_data, trajectory_data)
train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
# Initialize the model, criterion, and optimizer
model = CNN()
criterion = nn.MSELoss()  # Using MSE loss as mentioned in the paper for trajectory prediction
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Training loop
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, trajectories) in enumerate(train_loader):
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, trajectories)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{total_step}], Loss: {loss.item():.4f}')

print('Finished Training')
# Out:
# Epoch [1/5], Step [10/16], Loss: 1.1819
# Epoch [2/5], Step [10/16], Loss: 0.9890
# Epoch [3/5], Step [10/16], Loss: 0.9206
# Epoch [4/5], Step [10/16], Loss: 1.0527
# Epoch [5/5], Step [10/16], Loss: 0.9856
# Finished Training

# %%
#The goal is to create models that map visual inputs (images) to trajectory weights for robotic path planning.
#(MLP)The model consists of three fully connected layers with ReLU activations
#The MLP receives a flattened image (128x128x3 pixels).
#(CNN)The CNN processes an image (128x128x3 pixels).
#It includes convolutional layers followed by pooling layers and fully connected layers.
#The CNN outputs a vector representing trajectory weights.
#The MLP and CNN are trained using Mean Squared Error (MSE) loss and the Adam optimizer.
